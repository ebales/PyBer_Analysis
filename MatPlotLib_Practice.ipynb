# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create the plot and add a label for the legend
plt.plot(x_axis, y_axis, marker="*", color = "blue", linewidth = 2, label='Boston')
# Create labels for the x and y axes
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Set the y limit between 0 and 45
plt.ylim(0,45)
# Create a title
plt.title("PyBer Fare by Month")
# Add a grid
plt.grid()
# Add the legend
plt.legend()

# %%
# Create the plot with ax.plt()
fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis, color = "green", marker = "D", linewidth = 2, label = 'Boston')
ax.legend()
ax.set_title("PyBer Fare by Month")
ax.set_xlabel('Month')
ax.set_ylabel('Fare($)')
ax.set_ylim(0,45)
ax.grid()

# %%
# Create a bar chart using matplotlib
plt.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create the plot
plt.bar(x_axis, y_axis, color = "green", label = 'Boston')
# Create the labels ofr x and y axes
plt.xlabel("Date")
plt.ylabel("Fare($)")
# Create a title
plt.title("PyBer Fare by Month")
# Add the legend
plt.legend()

# %%
# Create horizontal bar chart
# And re-order the y axis
plt.barh(x_axis, y_axis, color = "magenta", label = 'Boston')
plt.gca().invert_yaxis()
plt.legend()
plt.xlabel("Fare($)")
plt.ylabel("Month")
plt.title("PyBer Fare by Month")
# Out:
# Text(0.5, 1.0, 'PyBer Fare by Month')

# %%
# Create the plot with ax.plt()
fig,ax = plt.subplots()
ax.bar(x_axis, y_axis)
# Out:
# <BarContainer object of 12 artists>

# %%
# Create horizontal plot with the ax.plt()
fig, ax = plt.subplots()
ax.barh(x_axis, y_axis, color = "cyan", label = 'Chicago')
ax.set_xlabel("Fare($)")
ax.set_ylabel("Month")
ax.set_title("PyBer Fare by Month")
ax.legend()
ax.invert_yaxis()

# %%
plt.plot(x_axis,y_axis,'o')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(y_axis,x_axis, color = "red", label = 'Chicago')
plt.ylabel("Month")
plt.xlabel("Fare($)")
plt.title("PyBer Fare by Month")
plt.legend()
plt.xlim(0,50)
plt.gca().invert_yaxis()

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.scatter(x_axis,y_axis,s=y_axis)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data*3)

# %%
plt.scatter(y_axis, x_axis, s= [i*5 for i in y_axis], color = "skyblue", alpha=0.8, edgecolor="black", linewidth=2, label='Boston',)
plt.title("PyBer Fares by Month")
plt.xlim(0,50)
plt.gca().invert_yaxis()
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.pie(y_axis, labels = x_axis)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.subplots(figsize=(8,8))
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0,0,0,0,0,0,0.2,0,0,0,0,0)
plt.pie(y_axis, 
        explode = explode_values, 
        colors=colors,
        labels=x_axis, 
        autopct='%.1f%%')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
explode = (0,0,0.2,0,0,0,0.2,0,0,0,0,0)
fig, ax = plt.subplots()
ax.pie(y_axis, 
       labels = x_axis, 
      autopct = '%.1f%%',
       radius = 2,
       explode = explode,
       shadow = True,
       startangle = 85,
    
      )
    
plt.show()
# Out:
#   File "C:\Users\eliza\AppData\Local\Temp/ipykernel_21400/4150211496.py", line 10
#     ax.invert_yaxis()
#     ^
# SyntaxError: positional argument follows keyword argument
